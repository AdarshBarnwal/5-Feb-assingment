# %%
                 5 FEBRUARY ASSINGMENT

# %%
Q1. 
Ans:-

Class: -
A class (in an Object-oriented programming) is a user-defined blueprint or prototype from which objects are created.
classes provide a means of building data and functionality together. creating a new class creates a new type of 
object, allowing new instances of that type to be made. each class instance can have attributes attached to it for
maintaining its state.

for example
consider the class of cars. there may be many carsw with different names and brand but all of them will share some 
common properties like all of theme will have 4 wheels, speed limit,milege range etc. so here, car is the class and
wheels, speed limits milege are their properties.

syntax: class definition
class classname:
    # statement
    
Object:-
An object os identifiable entity with some characteristics and behaviour. An object ia an instance of a class.
when a class is defined , no memory is allocated but when an object is created memory is allocated.

when a program is executed the objects interact by sending messages to one onother.

Each object cotaons data and code to manipulate lthe data object can intract without having to know details
of each others data or code, it is sufficient to know the type os message accepted and type of responce
returned by the objects.

syntax: object definition
obj = classname()
print(obj.atrr)

# example

calss bike:              # definition of class
    name = ""
    gear = 0
    
bike1.gear = Bike()        # create object of class
bike1.name = "mountain bike"

print(f"name: {bike1.name}, gears: {bike1.gear} " )

# %%
Q2.
Ans:-

inheritance,polymorphism,encapsulation and abstraction are the four pillars of oops.

# %%
Q3.
Ans:- 

The __init__ () function is a constructors are used to initialize the objects state. like methods, a constructor
also contains a collection of statements(i.e. instructions) that are executed at the time of lobject creation.
it runs as soon as an object of a class is instantiated. the method is useful to do any initialization we want to
do with our object.

#example
class student1:
    #init function
    def __init__(self,name,address):
        self.name = name
        self.address = address
    def intro (self):
        print("hello, my name is " ,self.name,"\nI am from ",self.address)
        
st= student1("Adarsh","mairwa")
st.intro()

# %%
Q4.
Ans:-

actually, the self parameter is a reference to the current instance of the class, and is used to access variables
that belongs to the class.

it does not have to named self ,we can call it whatever we like, but it has tobe the first parameter
of any function in the class.

#for example

calss self_parameter:
    
    def __init__(self,data):
        
        self.data = data
        
    def use_of_self(self):
        
        print(self.data)
        
sf= self_parameter(input("Enter your name:-"))

sf.use_of_self()

# %%
Q5.

inheritance is the ability to inherit features or attributes from already written classes into newer classes we make.
These features and attributes are defined data structures and the functions we can perform with them.
it promotes code reusability, which is considered one of the best industrial coding practices as 
it makes the code base modular.

parent class is the class being inherited from, also called base class.
child class is the class that inharits from another class, also called derived class.

types of inheritance area:-
single inheritance
multiple inheritance
multilevel inheritance
hierarchical inharitance
hybrid inheritance

# single inheritance

when a child class inherits only a single parent class.
# example

class parent:
    def func1(self):
        print("i am in function 1")
class child(parent):
    def func2(self):
        print("i am in function 2")
ob = child()
ob.func1()
ob.func2()

# multiple inheritance

when a child class becomes a parent class for another child class.

# example 

class parent:
    def func1(self):
        print("i am infuction 1")
class child(parent):
    def func2(self):
        print("i am in function 2")
class child2(child):
    def func3("i am in function 3")
ob = child child2()
ob.func1()
ob.func2()
ob.func3()

# hierarchical inharitance

hierarchical inheritance involves multiple inheritance from the same base or parent class.

# example 

class parent:
    def func1(self):
        print("i am infuction 1")
class child(parent):
    def func2(self):
        print("i am in function 2")
class child2(parent):
    def func3(self):
        print("i am in function 3")
ob = child()
ob1 = child2()
ob.func1()
ob.func2()

#hybrid inheritance

hybrid inheritance involves multiple inheritance taking place in a single program.

#example

class parent:
    def func1(self):
        print("i am infuction 1")
        
class child(parent):
    def func2(self):
        print("i am in function 2")

class child1(parent):
    def func3(self):
        print("i am in function 3")
        
        
class child3(parent,child1):
    def func4("i am in function 4")
ob = child3()
ob.func1()
